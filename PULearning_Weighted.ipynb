# %%
# !pip install ucimlrepo

# !pip install pulearn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 60.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 79.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import numpy as np
import pandas as pd

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id=17)

# data (as pandas dataframes)
X = breast_cancer_wisconsin_diagnostic.data.features
y = breast_cancer_wisconsin_diagnostic.data.targets

# # metadata
# print(breast_cancer_wisconsin_diagnostic.metadata)

# # variable information
# print(breast_cancer_wisconsin_diagnostic.variables)

X.head()
# y.head()
# Out:
#    radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0    17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1    20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2    19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3    11.42     20.38       77.58   386.1      0.14250       0.28390
# 4    20.29     14.34      135.10  1297.0      0.10030       0.13280
#
#    concavity1  concave_points1  symmetry1  fractal_dimension1  ...  radius3  \
# 0      0.3001          0.14710     0.2419             0.07871  ...    25.38
# 1      0.0869          0.07017     0.1812             0.05667  ...    24.99
# 2      0.1974          0.12790     0.2069             0.05999  ...    23.57
# 3      0.2414          0.10520     0.2597             0.09744  ...    14.91
# 4      0.1980          0.10430     0.1809             0.05883  ...    22.54
#
#    texture3  perimeter3   area3  smoothness3  compactness3  concavity3  \
# ...

# %%
print(y.value_counts())        # Shows counts of each unique value
print(y.nunique())             # Shows number of unique values
# Out:
# Diagnosis
# B            357
# M            212
# Name: count, dtype: int64
# Diagnosis    2
# dtype: int64

# %%
# in y, add a column actual_label where int 1 for M in diagnosis and 0 for B or otherwise

y['actual_label'] = np.where(y['Diagnosis'] == 'M', 1, 0).astype(int)

y.head()
# Out:
# /tmp/ipython-input-1069830402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['actual_label'] = np.where(y['Diagnosis'] == 'M', 1, 0).astype(int)
#   Diagnosis  actual_label
# 0         M             1
# 1         M             1
# 2         M             1
# 3         M             1
# 4         M             1

# %%
# in y, add a column observed_label where only 70% of 1 in actual_label get 1 other get 0

mask = y["actual_label"] == 1

# Each actual_label M 70% chance of being labeled
y.loc[mask, "observed_label"] = np.random.binomial(1, 0.7, size=mask.sum())

y["observed_label"] = y["observed_label"].fillna(0).astype(int)
y["observed_label"] = y["observed_label"].astype(int)

# even tho save as int, np.random.binomial function used to generate these values returns a NumPy array of floats by default.
y.head()
# Out:
# /tmp/ipython-input-2072473407.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y.loc[mask, "observed_label"] = np.random.binomial(1, 0.7, size=mask.sum())
# /tmp/ipython-input-2072473407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y["observed_label"] = y["observed_label"].fillna(0).astype(int)
# /tmp/ipython-input-2072473407.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Print the num of actual positives, observed positives and hidden positives with proper verbose

num_actual_positives = y['actual_label'].sum()
num_observed_positives = y['observed_label'].sum().astype(int)

num_hidden_positives = num_actual_positives - num_observed_positives

print(f"Number of actual positives: {num_actual_positives}")
print(f"Number of observed positives: {num_observed_positives}")
print(f"Number of hidden positives: {num_hidden_positives}")
# Out:
# Number of actual positives: 212
# Number of observed positives: 145
# Number of hidden positives: 67

# %%
# #combine X and y (could do separately but need to keep track of indices)

# # Combine X and y into one DataFrame
# wisc_df = pd.concat([X, y], axis=1)

# # Check the result
# print(wisc_df.head())

y_observed = y['observed_label']

#yobs unique count and sum
print(y_observed.value_counts())
# Out:
# observed_label
# 0    424
# 1    145
# Name: count, dtype: int64

# %%
# split data in 80/20 train test using sklearn

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y_observed, test_size=0.3, random_state=42, stratify=y['actual_label'])

# %%
# After test train split, create a variable to keep track of all original indices in y_test

y_test_original_indices = y_test.index

print(y_test_original_indices)
# Out:
# Index([448, 346, 568, 411, 519, 527,   4, 440, 479, 310,
#        ...
#         88, 130,  71,  60, 459,  74,  39,  99, 115, 219],
#       dtype='int64', length=171)

# %%
# obtain corresponding original label from these indices and save as y_test_original_label

y_test_original_label = y.loc[y_test_original_indices, 'actual_label']

print(y_test_original_label)
# Out:
# 448    0
# 346    0
# 568    0
# 411    0
# 519    0
#       ..
# 74     0
# 39     1
# 99     1
# 115    0
# 219    1
# Name: actual_label, Length: 171, dtype: int64

# %%
# create a dataframe that has that has y_test_observed labels and y_test_original_labels side by side. but the indices should match

y_test_df = pd.DataFrame({'observed_label': y_test, 'actual_label': y_test_original_label})

print(y_test_df)
# Out:
#      observed_label  actual_label
# 448               0             0
# 346               0             0
# 568               0             0
# 411               0             0
# 519               0             0
# ..              ...           ...
# 74                0             0
# 39                1             1
# 99                1             1
# 115               0             0
# 219               1             1
#
# [171 rows x 2 columns]

# %%
#check if how many labels in observed label dont match with actual label in each row
print(len(y_test_df[y_test_df['observed_label'] != y_test_df['actual_label']]))


# print type of y_test and y_test_original_label
print(type(y_test))
print(type(y_test_original_label))
# Out:
# 18
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
print("Original:", y_observed.value_counts(normalize=True))
print("Train:", y_train.value_counts(normalize=True))
print("Test:", y_test.value_counts(normalize=True))
print("\n\nUnique y_train count: ", y_train.value_counts())
# Out:
# Original: observed_label
# 0    0.745167
# 1    0.254833
# Name: proportion, dtype: float64
# Train: observed_label
# 0    0.751256
# 1    0.248744
# Name: proportion, dtype: float64
# Test: observed_label
# 0    0.730994
# 1    0.269006
# Name: proportion, dtype: float64
#
#
# Unique y_train count:  observed_label
# 0    299
# 1     99
# Name: count, dtype: int64

# %%
# unlabeled and labeled counts in y_train
unlabeled_count, labeled_count = y_train.value_counts()
print(y_train.value_counts())

# Get indices of known positive (labeled) and unlabeled examples
labeled_indices = y_train[y_train == 1].index
unlabeled_indices = y_train[y_train == 0].index
# Out:
# observed_label
# 0    299
# 1     99
# Name: count, dtype: int64

# %%
print(labeled_indices)
print(unlabeled_indices)
# Out:
# Index([330, 414,  15,  28,  29, 444, 201, 417, 274,  24, 498, 565, 134,   1,
#         31,  13,  45, 184, 373,   9, 258, 161,  38, 446, 352,  82,   0, 197,
#        164,  10, 264, 392, 262, 430, 328,  17,  54, 509, 516, 323, 564, 105,
#         43,  26,   2, 501,  35, 489, 370, 121, 119,  40, 366, 138, 372, 261,
#        146,   8, 182, 263,  36, 168,  95, 337,  42, 253, 194, 180, 210, 108,
#        172, 449, 351, 260, 252, 126, 353, 255, 400, 156, 254, 317, 512, 535,
#        135, 365, 521, 369, 132, 514,  41, 297,  87, 236, 212,  62, 339,  65,
#        129],
#       dtype='int64')
# Index([ 78, 378, 213,  89,  32, 240, 251, 486, 315, 292,
#        ...
#         59, 549,  92, 333, 324, 192,  37, 415, 458, 476],
#       dtype='int64', length=299)

# %%
# # define baseline model - Logistic Regression

# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import f1_score

# lr_model = LogisticRegression(max_iter=500)

# lr_model

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import f1_score

lr_model = make_pipeline(
    StandardScaler(),
    LogisticRegression()
)

# %%
# fit lr model and calculate f1 score on test-set

lr_model.fit(X_train, y_train)
lr_preds = lr_model.predict(X_test)

f1_lr = f1_score(y_test, lr_preds)
print(f"Baseline F1 score (supervised LR): {f1_lr:.4f}")
# Out:
# Baseline F1 score (supervised LR): 0.6154

# %%
# reconsidering testing with x_test_original_label

f1_lr_actual_labels = f1_score(y_test_original_label, lr_preds)
print(f"Baseline F1 score (supervised LR): {f1_lr_actual_labels:.4f}")
# Out:
# Baseline F1 score (supervised LR): 0.6667

# %%
assert all(X_train.index == y_train.index)  # Only if both are pandas DataFrames/Series
X_train.shape
# Out:
# (398, 30)

# %%
# DOING THIS FOR MISMATCH WITH WeightedElkanotoPuClassifier

# Ensure X_train is a DataFrame with 0-based row indices
if isinstance(X_train, pd.DataFrame):
    X_train = X_train.reset_index(drop=True)
    X_train = np.array(X_train)

# If y_train is a DataFrame/Series, reset index and convert to NumPy
if isinstance(y_train, (pd.Series, pd.DataFrame)):
    y_train = y_train.reset_index(drop=True)
    y_train = np.array(y_train)

# Now safely get 0-based row indices
labeled_indices = np.where(y_train == 1)[0]
unlabeled_indices = np.where(y_train == 0)[0]

# %%
# train and test on weighted PU

from pulearn import WeightedElkanotoPuClassifier

pu_lr_model = make_pipeline(
    StandardScaler(),
    LogisticRegression()
)

pu_estimator = WeightedElkanotoPuClassifier(
    estimator=pu_lr_model, labeled=labeled_count, unlabeled=unlabeled_count, hold_out_ratio=0.2)
pu_estimator.fit(X_train, y_train)
# Out:
# WeightedElkanotoPuClassifier(estimator=Pipeline(steps=[('standardscaler',
#                                                         StandardScaler()),
#                                                        ('logisticregression',
#                                                         LogisticRegression())]),
#                              hold_out_ratio=0.2, labeled=99, unlabeled=299)

# %%
# Convert X_test to numpy array if needed
X_test = np.array(X_test)

# Get predicted probabilities for positive class on test data
y_proba = pu_estimator.predict_proba(X_test)[:, 1]

# Choose threshold (default 0.5)
threshold = 0.5

# Generate predictions based on threshold
y_pred = (y_proba >= threshold).astype(int)

# Calculate F1 score
f1_pu = f1_score(y_test, y_pred)
print(f"F1 score: {f1_pu:.4f}")
# Out:
# F1 score: 0.7000

# %%
# Calculate F1 score based on y_test_original_label

#y_test_original_label = np.array(y_test_original_label)

f1_pu_actual_labels = f1_score(y_test_original_label, y_pred)
print(f"F1 score: {f1_pu_actual_labels:.4f}")
# Out:
# F1 score: 0.8644

# %%
print(f"Baseline F1 score (supervised LR): {f1_lr:.4f}")
print(f"PU-Learning F1 score (estimator LR): {f1_pu:.4f}")
# Out:
# Baseline F1 score (supervised LR): 0.6512
# PU-Learning F1 score (estimator LR): 0.7200

# %%
# WeightedElkanotoPuClassifier OFFICIAL DEFINITION

class WeightedElkanotoPuClassifier(BaseEstimator, ClassifierMixin):
    """Positive-unlabeled classifier using the weighted Elkan & Noto method.

    See the original paper for details on how the `labeled` and `unlabeled`
    quantities are used to weigh training examples and affect the learning
    process:
    https://cseweb.ucsd.edu/~elkan/posonly.pdf

    Parameters
    ----------
    estimator : sklearn.BaseEstimator
        Any sklearn-compliant estimator object implementing the fit() and
        predict_proba() methods.
    labeled : int
        The cardinality to attribute to the labeled training set.
    unlabeled : int
        The cardinality to attribute to the unlabeled training set.
    hold_out_ratio : float, default 0.1
       The ratio of training examples to set aside to estimate the probability
       of an exmaple to be positive.
    """

    def __init__(self, estimator, labeled, unlabeled, hold_out_ratio=0.1):
        self.estimator = estimator
        self.c = 1.0
        self.hold_out_ratio = hold_out_ratio
        self.labeled = labeled
        self.unlabeled = unlabeled
        self.estimator_fitted = False

    def __str__(self):
        return 'Estimator: {}\np(s=1|y=1,x) ~= {}\nFitted: {}'.format(
            self.estimator,
            self.c,
            self.estimator_fitted,
        )

    def fit(self, X, y):
        """Fits the classifier

        Parameters
        ----------
        X : array-like, shape = [n_samples, n_features]
            The training input samples.
        y : array-like, shape = [n_samples]
            The target values. An array of int.

        Returns
        -------
        self : object
            Returns self.
        """
        positives = np.where(y == 1.0)[0]
        hold_out_size = int(np.ceil(len(positives) * self.hold_out_ratio))
        # check for the required number of positive examples
        if len(positives) <= hold_out_size:
            raise ValueError(
                'Not enough positive examples to estimate p(s=1|y=1,x).'
                ' Need at least {}.'.format(hold_out_size + 1)
            )
        # construct the holdout set
        np.random.shuffle(positives)
        hold_out = positives[:hold_out_size]
        X_hold_out = X[hold_out]
        X = np.delete(X, hold_out, 0)
        y = np.delete(y, hold_out)
        # fit the inner estimator
        self.estimator.fit(X, y)
        hold_out_predictions = self.estimator.predict_proba(X_hold_out)
        hold_out_predictions = hold_out_predictions[:, 1]
        # update c, the positive proba estimate
        c = np.mean(hold_out_predictions)
        self.c = c
        self.estimator_fitted = True

    # Returns E[y] which is P(y=1)
    def _estimateEy(self, G):
        n = self.labeled
        m = self.labeled + self.unlabeled
        G = G[:, 1]
        np.place(G, G == 1.0, 0.999)
        W = (G / (1 - G)) * ((1 - self.c) / self.c)
        return (float(n) + float(W.sum())) / float(m)

    def predict_proba(self, X):
        """Predict class probabilities for X.

        Parameters
        ----------
        X : array-like of shape = [n_samples, n_features]
            The input samples.

        Returns
        -------
        p : array of shape = [n_samples, n_classes]
            The class probabilities of the input samples. The order of the
            classes corresponds to that in the attribute classes_.
        """
        if not self.estimator_fitted:
            raise NotFittedError(
                'The estimator must be fitted before calling predict_proba().'
            )
        n = self.labeled
        m = self.labeled + self.unlabeled
        # self.estimator.predict_proba gives the probability of P(s=1|x)
        # for x belongs to P or U
        probabilistic_predictions = self.estimator.predict_proba(X)
        yEstimate = self._estimateEy(probabilistic_predictions)
        probabilistic_predictions = probabilistic_predictions[:, 1]
        numerator = probabilistic_predictions * (self.c * yEstimate * m)
        return numerator / float(n)

    def predict(self, X, treshold=0.5):
        """Predict labels.

        Parameters
        ----------
        X : array-like of shape = [n_samples, n_features]
            The input samples.
        threshold : float, default 0.5
            The decision threshold over probability to warrent a
            positive label.

        Returns
        -------
        y : array of int of shape = [n_samples]
            Predicted labels for the given inpurt samples.
        """
        if not self.estimator_fitted:
            raise NotFittedError(
                'The estimator must be fitted before calling predict().'
            )
        return np.array([
            1.0 if p > treshold else -1.0
            for p in self.predict_proba(X)
        ])
